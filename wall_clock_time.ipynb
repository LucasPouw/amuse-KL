# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# n_cores = np.array([1,2,4,6,8,12,16,24,32])
# times = np.array([146.01, 81.83, 65.93, 43.14, 32.26, 15.10, 12.26, 12.16, 11.03])

n_cores2 = [1,2,4,8,16,32]
times1k = [2.6,7.8,0.51,0.29,0.35,0.18]
times10k = [15.21,10.65,5.83,2.79,1.58,1.24]
times100k = [149,82,67,32,19,10]

plt.plot(n_cores2, times1k, marker='o', label='1k')
plt.plot(n_cores2, times10k, marker='o', label='10k')
plt.plot(n_cores2, times100k, marker='o', label='100k')
plt.yscale('log')
plt.xlabel('Number of Cores')
plt.ylabel('Wall Clock Time (s)')
plt.legend()
plt.show()

# #efficiency
# efficiency = times[0] / (n_cores * times)
# plt.plot(n_cores, efficiency, marker='o')
# plt.xlabel('Number of Cores')
# plt.ylabel('Efficiency')

# %%
from amuse.io import read_set_from_file

# %%
bodies = read_set_from_file("/home/ybadoux/AMUSE/hermite_hists/snapshot_25530429_4.45.hdf5")
print(bodies)
# Out:
#                  key           lx           ly           lz         mass         name       radius  sink_radius            u           vx           vy           vz            x            y            z
#                    -  0.001 * m**2 * kg * s**-1  0.001 * m**2 * kg * s**-1  0.001 * m**2 * kg * s**-1  1.98892e+30 * kg         none  695500000.0 * m  695500000.0 * m  m**2 * s**-2  8028481.01748 * m * s**-1  8028481.01748 * m * s**-1  8028481.01748 * m * s**-1  3.08567758128e+16 * m  3.08567758128e+16 * m  3.08567758128e+16 * m
# ====================  ===========  ===========  ===========  ===========  ===========  ===========  ===========  ===========  ===========  ===========  ===========  ===========  ===========  ===========
#   629745486261858486    0.000e+00    0.000e+00    0.000e+00    4.297e+06         SMBH    1.700e+01    1.700e+01    0.000e+00    2.454e-08   -4.316e-08   -1.648e-13   -4.338e-08   -1.626e-08    2.441e-12
# ...
